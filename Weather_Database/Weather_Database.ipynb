# %% [markdown]
# ## Deliverable 1.

# %%
import pandas as pd
import numpy as np

# %%
# Create a new list of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
# Create a list to hold the nearest city data using the citipy module
from citipy import citipy

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 765

# %%
# Perform an API call with the OpenWeatherMap
import requests
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a list to hold the weather data of the nearest cities
import time

city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | xilitla
# Processing Record 3 of Set 1 | atuona
# Processing Record 4 of Set 1 | mar del plata
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | kalianget
# Processing Record 8 of Set 1 | cidreira
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | thinadhoo
# Processing Record 11 of Set 1 | bignona
# Processing Record 12 of Set 1 | taunggyi
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | nikolskoye
# Processing Record 15 of Set 1 | merauke
# Processing Record 16 of Set 1 | pevek
# Processing Record 17 of Set 1 | kapaa
# Processing Record 18 of Set 1 | hithadhoo
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | digoin
# Processing Record 21 of Set 1 | kavieng
# Processing Record 22 of Set 1 | esperance
# Processing Record 23 of Set 1 | rodez
# Processing Record 24 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 1 | bethel
# Processing Record 26 of Set 1 | tuatapere
# Processing Record 27 of Set 1 | faanui
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | caravelas
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | port elizabeth
# Processing Record 32 of Set 1 | qaqortoq
# Processing Record 33 of Set 1 | narsaq
# Processing Record 34 of Set 1 | okato
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | hamilton
# Processing Record 37 of Set 1 | provideniya
# Processing Record 38 of Set 1 | rehoboth
# Processing Record 39 of Set 1 | jardim
# Processing Record 40 of Set 1 | sumbawa
# City not found. Skipping...
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | kushima
# Processing Record 43 of Set 1 | bara
# Processing Record 44 of Set 1 | puerto leguizamo
# Processing Record 45 of Set 1 | yellowknife
# Processing Record 46 of Set 1 | klaksvik
# Processing Record 47 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 1 | severo-kurilsk
# Processing Record 49 of Set 1 | port macquarie
# Processing Record 50 of Set 1 | sao filipe
# Processing Record 1 of Set 2 | arona
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | longyearbyen
# Processing Record 4 of Set 2 | krasnoselkup
# Processing Record 5 of Set 2 | maracas
# Processing Record 6 of Set 2 | fukue
# Processing Record 7 of Set 2 | livramento
# Processing Record 8 of Set 2 | sars
# Processing Record 9 of Set 2 | cap malheureux
# Processing Record 10 of Set 2 | hobart
# Processing Record 11 of Set 2 | lebu
# Processing Record 12 of Set 2 | hambantota
# Processing Record 13 of Set 2 | tiksi
# Processing Record 14 of Set 2 | bud
# Processing Record 15 of Set 2 | ushuaia
# Processing Record 16 of Set 2 | cornwall
# Processing Record 17 of Set 2 | grand gaube
# Processing Record 18 of Set 2 | barrow
# Processing Record 19 of Set 2 | kununurra
# Processing Record 20 of Set 2 | rocha
# Processing Record 21 of Set 2 | malkangiri
# Processing Record 22 of Set 2 | aksu
# Processing Record 23 of Set 2 | cazaje
# City not found. Skipping...
# Processing Record 24 of Set 2 | mazatlan
# Processing Record 25 of Set 2 | auki
# Processing Record 26 of Set 2 | cape town
# Processing Record 27 of Set 2 | gilbues
# Processing Record 28 of Set 2 | tromso
# Processing Record 29 of Set 2 | nekhayevskiy
# Processing Record 30 of Set 2 | bontang
# Processing Record 31 of Set 2 | ponta delgada
# Processing Record 32 of Set 2 | tigil
# Processing Record 33 of Set 2 | castro
# Processing Record 34 of Set 2 | new norfolk
# Processing Record 35 of Set 2 | teya
# Processing Record 36 of Set 2 | dire
# Processing Record 37 of Set 2 | ayagoz
# Processing Record 38 of Set 2 | dien bien
# City not found. Skipping...
# Processing Record 39 of Set 2 | hervey bay
# Processing Record 40 of Set 2 | anito
# Processing Record 41 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 2 | amapa
# Processing Record 43 of Set 2 | dikson
# Processing Record 44 of Set 2 | shingu
# Processing Record 45 of Set 2 | saint-philippe
# Processing Record 46 of Set 2 | hobyo
# Processing Record 47 of Set 2 | port said
# Processing Record 48 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 49 of Set 2 | jiehu
# Processing Record 50 of Set 2 | robertsport
# Processing Record 1 of Set 3 | inuvik
# Processing Record 2 of Set 3 | bluff
# Processing Record 3 of Set 3 | motala
# Processing Record 4 of Set 3 | broken hill
# Processing Record 5 of Set 3 | taltal
# Processing Record 6 of Set 3 | nueva loja
# Processing Record 7 of Set 3 | mahanoro
# Processing Record 8 of Set 3 | kodiak
# Processing Record 9 of Set 3 | oistins
# Processing Record 10 of Set 3 | kawana waters
# City not found. Skipping...
# Processing Record 11 of Set 3 | georgetown
# Processing Record 12 of Set 3 | tawnat
# City not found. Skipping...
# Processing Record 13 of Set 3 | mount gambier
# Processing Record 14 of Set 3 | salalah
# Processing Record 15 of Set 3 | parana
# Processing Record 16 of Set 3 | marrakesh
# Processing Record 17 of Set 3 | clyde river
# Processing Record 18 of Set 3 | port alfred
# Processing Record 19 of Set 3 | maceio
# Processing Record 20 of Set 3 | stolin
# Processing Record 21 of Set 3 | los llanos de aridane
# Processing Record 22 of Set 3 | kerrville
# Processing Record 23 of Set 3 | gigmoto
# Processing Record 24 of Set 3 | grindavik
# Processing Record 25 of Set 3 | airai
# Processing Record 26 of Set 3 | wrexham
# Processing Record 27 of Set 3 | arraial do cabo
# Processing Record 28 of Set 3 | butaritari
# Processing Record 29 of Set 3 | jati
# Processing Record 30 of Set 3 | lorengau
# Processing Record 31 of Set 3 | sitka
# Processing Record 32 of Set 3 | albany
# Processing Record 33 of Set 3 | matay
# Processing Record 34 of Set 3 | chuy
# Processing Record 35 of Set 3 | munster
# Processing Record 36 of Set 3 | darnah
# Processing Record 37 of Set 3 | saurimo
# Processing Record 38 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 3 | miyako
# Processing Record 40 of Set 3 | ribeira grande
# Processing Record 41 of Set 3 | ashland
# Processing Record 42 of Set 3 | lompoc
# Processing Record 43 of Set 3 | luderitz
# Processing Record 44 of Set 3 | ulaangom
# Processing Record 45 of Set 3 | avarua
# Processing Record 46 of Set 3 | flinders
# Processing Record 47 of Set 3 | waggaman
# Processing Record 48 of Set 3 | ixtapa
# Processing Record 49 of Set 3 | palembang
# Processing Record 50 of Set 3 | gambat
# Processing Record 1 of Set 4 | nilopolis
# Processing Record 2 of Set 4 | belmonte
# Processing Record 3 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 4 | vardo
# Processing Record 5 of Set 4 | forquilhinha
# Processing Record 6 of Set 4 | zlitan
# Processing Record 7 of Set 4 | sahbuz
# Processing Record 8 of Set 4 | ostrovnoy
# Processing Record 9 of Set 4 | vila franca do campo
# Processing Record 10 of Set 4 | saskylakh
# Processing Record 11 of Set 4 | varna
# Processing Record 12 of Set 4 | laguna
# Processing Record 13 of Set 4 | nanortalik
# Processing Record 14 of Set 4 | ancud
# Processing Record 15 of Set 4 | puerto el triunfo
# Processing Record 16 of Set 4 | nokha
# Processing Record 17 of Set 4 | morehead
# Processing Record 18 of Set 4 | sungaipenuh
# Processing Record 19 of Set 4 | galveston
# Processing Record 20 of Set 4 | cherskiy
# Processing Record 21 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 4 | mahebourg
# Processing Record 23 of Set 4 | san lorenzo
# Processing Record 24 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 4 | san patricio
# Processing Record 26 of Set 4 | maneadero
# Processing Record 27 of Set 4 | muravlenko
# Processing Record 28 of Set 4 | kulunda
# Processing Record 29 of Set 4 | rochegda
# Processing Record 30 of Set 4 | mumford
# Processing Record 31 of Set 4 | pozo colorado
# Processing Record 32 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 33 of Set 4 | rabo de peixe
# Processing Record 34 of Set 4 | yanan
# City not found. Skipping...
# Processing Record 35 of Set 4 | thompson
# Processing Record 36 of Set 4 | nuuk
# Processing Record 37 of Set 4 | nenjiang
# Processing Record 38 of Set 4 | egvekinot
# Processing Record 39 of Set 4 | vila velha
# Processing Record 40 of Set 4 | tasiilaq
# Processing Record 41 of Set 4 | qaanaaq
# Processing Record 42 of Set 4 | kahului
# Processing Record 43 of Set 4 | saint george
# Processing Record 44 of Set 4 | mandalgovi
# Processing Record 45 of Set 4 | jumla
# Processing Record 46 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 4 | mandurah
# Processing Record 48 of Set 4 | yueyang
# Processing Record 49 of Set 4 | liverpool
# Processing Record 50 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 1 of Set 5 | pontian kecil
# Processing Record 2 of Set 5 | namibe
# Processing Record 3 of Set 5 | chokurdakh
# Processing Record 4 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 5 of Set 5 | novoagansk
# Processing Record 6 of Set 5 | abnub
# Processing Record 7 of Set 5 | chantada
# Processing Record 8 of Set 5 | takoradi
# Processing Record 9 of Set 5 | gamba
# Processing Record 10 of Set 5 | ponta do sol
# Processing Record 11 of Set 5 | itarema
# Processing Record 12 of Set 5 | bemban
# Processing Record 13 of Set 5 | havoysund
# Processing Record 14 of Set 5 | vagur
# Processing Record 15 of Set 5 | cayenne
# Processing Record 16 of Set 5 | tuktoyaktuk
# Processing Record 17 of Set 5 | khatanga
# Processing Record 18 of Set 5 | san cristobal
# Processing Record 19 of Set 5 | phibun mangsahan
# Processing Record 20 of Set 5 | kargil
# Processing Record 21 of Set 5 | awjilah
# Processing Record 22 of Set 5 | troitskoye
# Processing Record 23 of Set 5 | acapulco
# Processing Record 24 of Set 5 | asau
# Processing Record 25 of Set 5 | makakilo city
# Processing Record 26 of Set 5 | black river
# Processing Record 27 of Set 5 | san luis
# Processing Record 28 of Set 5 | aklavik
# Processing Record 29 of Set 5 | nyurba
# Processing Record 30 of Set 5 | vredendal
# Processing Record 31 of Set 5 | alyangula
# Processing Record 32 of Set 5 | east london
# Processing Record 33 of Set 5 | mandiana
# Processing Record 34 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 5 | vaitape
# Processing Record 36 of Set 5 | novaya malykla
# Processing Record 37 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 5 | padang
# Processing Record 39 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 5 | pangody
# Processing Record 41 of Set 5 | naze
# Processing Record 42 of Set 5 | kulhudhuffushi
# Processing Record 43 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 5 | mananjary
# Processing Record 45 of Set 5 | batemans bay
# Processing Record 46 of Set 5 | marfino
# Processing Record 47 of Set 5 | pacific grove
# Processing Record 48 of Set 5 | kaitangata
# Processing Record 49 of Set 5 | menemen
# Processing Record 50 of Set 5 | tiarei
# Processing Record 1 of Set 6 | maulvi bazar
# City not found. Skipping...
# Processing Record 2 of Set 6 | gillette
# Processing Record 3 of Set 6 | say
# Processing Record 4 of Set 6 | besikduzu
# Processing Record 5 of Set 6 | san jose del palmar
# Processing Record 6 of Set 6 | kommunisticheskiy
# Processing Record 7 of Set 6 | upernavik
# Processing Record 8 of Set 6 | kiunga
# Processing Record 9 of Set 6 | ijui
# Processing Record 10 of Set 6 | guerrero negro
# Processing Record 11 of Set 6 | paamiut
# Processing Record 12 of Set 6 | tsumeb
# Processing Record 13 of Set 6 | marawi
# Processing Record 14 of Set 6 | naantali
# Processing Record 15 of Set 6 | hualmay
# Processing Record 16 of Set 6 | roald
# Processing Record 17 of Set 6 | gayny
# Processing Record 18 of Set 6 | portland
# Processing Record 19 of Set 6 | homer
# Processing Record 20 of Set 6 | imeni poliny osipenko
# Processing Record 21 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 6 | komsomolskiy
# Processing Record 23 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 6 | baringo
# Processing Record 25 of Set 6 | balad
# Processing Record 26 of Set 6 | venustiano carranza
# Processing Record 27 of Set 6 | buraydah
# Processing Record 28 of Set 6 | hluti
# Processing Record 29 of Set 6 | victoria
# Processing Record 30 of Set 6 | gizo
# Processing Record 31 of Set 6 | zhezkazgan
# Processing Record 32 of Set 6 | soloneshnoye
# Processing Record 33 of Set 6 | norman wells
# Processing Record 34 of Set 6 | galle
# Processing Record 35 of Set 6 | dukhovshchina
# Processing Record 36 of Set 6 | paita
# Processing Record 37 of Set 6 | tandil
# Processing Record 38 of Set 6 | bozhou
# Processing Record 39 of Set 6 | bournemouth
# Processing Record 40 of Set 6 | vestmannaeyjar
# Processing Record 41 of Set 6 | tual
# Processing Record 42 of Set 6 | barstow
# Processing Record 43 of Set 6 | beloha
# Processing Record 44 of Set 6 | bacolod
# Processing Record 45 of Set 6 | touros
# Processing Record 46 of Set 6 | hasaki
# Processing Record 47 of Set 6 | atasu
# Processing Record 48 of Set 6 | iqaluit
# Processing Record 49 of Set 6 | cardston
# Processing Record 50 of Set 6 | saint austell
# Processing Record 1 of Set 7 | vanimo
# Processing Record 2 of Set 7 | sassandra
# Processing Record 3 of Set 7 | siocon
# Processing Record 4 of Set 7 | gorin
# Processing Record 5 of Set 7 | poum
# Processing Record 6 of Set 7 | tres arroyos
# Processing Record 7 of Set 7 | suleja
# Processing Record 8 of Set 7 | tomatlan
# Processing Record 9 of Set 7 | aginskoye
# Processing Record 10 of Set 7 | picton
# Processing Record 11 of Set 7 | guanare
# Processing Record 12 of Set 7 | san carlos de bariloche
# Processing Record 13 of Set 7 | romny
# Processing Record 14 of Set 7 | lewistown
# Processing Record 15 of Set 7 | seoul
# Processing Record 16 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 7 | vernon
# Processing Record 18 of Set 7 | dwarka
# Processing Record 19 of Set 7 | sabang
# Processing Record 20 of Set 7 | mayor pablo lagerenza
# Processing Record 21 of Set 7 | bambous virieux
# Processing Record 22 of Set 7 | lavrentiya
# Processing Record 23 of Set 7 | isla mujeres
# Processing Record 24 of Set 7 | batticaloa
# Processing Record 25 of Set 7 | methoni
# Processing Record 26 of Set 7 | kieta
# Processing Record 27 of Set 7 | xuanhua
# Processing Record 28 of Set 7 | erzurum
# Processing Record 29 of Set 7 | aneho
# Processing Record 30 of Set 7 | henties bay
# Processing Record 31 of Set 7 | porto torres
# Processing Record 32 of Set 7 | banda aceh
# Processing Record 33 of Set 7 | gimli
# Processing Record 34 of Set 7 | ugoofaaru
# Processing Record 35 of Set 7 | pisco
# Processing Record 36 of Set 7 | chabahar
# Processing Record 37 of Set 7 | monte cristi
# City not found. Skipping...
# Processing Record 38 of Set 7 | dasoguz
# Processing Record 39 of Set 7 | muzquiz
# City not found. Skipping...
# Processing Record 40 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 41 of Set 7 | tynset
# Processing Record 42 of Set 7 | carnarvon
# Processing Record 43 of Set 7 | yenagoa
# Processing Record 44 of Set 7 | olovyannaya
# Processing Record 45 of Set 7 | jaru
# Processing Record 46 of Set 7 | kruisfontein
# Processing Record 47 of Set 7 | hay river
# Processing Record 48 of Set 7 | floriano
# Processing Record 49 of Set 7 | fortuna
# Processing Record 50 of Set 7 | yefira
# City not found. Skipping...
# Processing Record 1 of Set 8 | codrington
# Processing Record 2 of Set 8 | oktyabrskiy
# Processing Record 3 of Set 8 | alashtar
# City not found. Skipping...
# Processing Record 4 of Set 8 | lerwick
# Processing Record 5 of Set 8 | gorkovskoye
# City not found. Skipping...
# Processing Record 6 of Set 8 | leh
# Processing Record 7 of Set 8 | tukrah
# Processing Record 8 of Set 8 | rodrigues alves
# Processing Record 9 of Set 8 | lagunas
# Processing Record 10 of Set 8 | zhigansk
# Processing Record 11 of Set 8 | urengoy
# Processing Record 12 of Set 8 | anan
# Processing Record 13 of Set 8 | marsh harbour
# Processing Record 14 of Set 8 | gravdal
# Processing Record 15 of Set 8 | shenjiamen
# Processing Record 16 of Set 8 | carpentras
# Processing Record 17 of Set 8 | ostersund
# Processing Record 18 of Set 8 | howard springs
# Processing Record 19 of Set 8 | yumen
# Processing Record 20 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 21 of Set 8 | isangel
# Processing Record 22 of Set 8 | fort nelson
# Processing Record 23 of Set 8 | nurota
# Processing Record 24 of Set 8 | mwene-ditu
# Processing Record 25 of Set 8 | dingle
# Processing Record 26 of Set 8 | yambio
# Processing Record 27 of Set 8 | aranos
# Processing Record 28 of Set 8 | berlevag
# Processing Record 29 of Set 8 | pimenta bueno
# Processing Record 30 of Set 8 | saldanha
# Processing Record 31 of Set 8 | shima
# Processing Record 32 of Set 8 | sao joao da barra
# Processing Record 33 of Set 8 | bandarbeyla
# Processing Record 34 of Set 8 | privokzalnyy
# City not found. Skipping...
# Processing Record 35 of Set 8 | jaciara
# Processing Record 36 of Set 8 | whitehorse
# Processing Record 37 of Set 8 | saquena
# Processing Record 38 of Set 8 | kavaratti
# Processing Record 39 of Set 8 | sudbury
# Processing Record 40 of Set 8 | fairbanks
# Processing Record 41 of Set 8 | nioro
# Processing Record 42 of Set 8 | mindelo
# Processing Record 43 of Set 8 | shchelyayur
# City not found. Skipping...
# Processing Record 44 of Set 8 | cockburn town
# Processing Record 45 of Set 8 | kokoda
# Processing Record 46 of Set 8 | kutum
# Processing Record 47 of Set 8 | lata
# Processing Record 48 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 8 | fortaleza
# Processing Record 50 of Set 8 | neuquen
# Processing Record 1 of Set 9 | hami
# Processing Record 2 of Set 9 | kalmunai
# Processing Record 3 of Set 9 | nisia floresta
# Processing Record 4 of Set 9 | alexandria
# Processing Record 5 of Set 9 | ankang
# Processing Record 6 of Set 9 | salym
# Processing Record 7 of Set 9 | ninghai
# Processing Record 8 of Set 9 | bubaque
# Processing Record 9 of Set 9 | dubai
# Processing Record 10 of Set 9 | susanville
# Processing Record 11 of Set 9 | baykit
# Processing Record 12 of Set 9 | husavik
# Processing Record 13 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 9 | nabire
# Processing Record 15 of Set 9 | kwinana
# Processing Record 16 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 9 | velikiy ustyug
# Processing Record 18 of Set 9 | norwich
# Processing Record 19 of Set 9 | puerto suarez
# Processing Record 20 of Set 9 | dicabisagan
# Processing Record 21 of Set 9 | aden
# Processing Record 22 of Set 9 | talnakh
# Processing Record 23 of Set 9 | eenhana
# Processing Record 24 of Set 9 | jahrom
# City not found. Skipping...
# Processing Record 25 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 9 | pangnirtung
# Processing Record 27 of Set 9 | roebourne
# Processing Record 28 of Set 9 | beringovskiy
# Processing Record 29 of Set 9 | nhamunda
# Processing Record 30 of Set 9 | novoseleznevo
# Processing Record 31 of Set 9 | cabo san lucas
# Processing Record 32 of Set 9 | shu
# Processing Record 33 of Set 9 | huilong
# Processing Record 34 of Set 9 | skagen
# Processing Record 35 of Set 9 | jalu
# Processing Record 36 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 9 | nemuro
# Processing Record 38 of Set 9 | algiers
# Processing Record 39 of Set 9 | faya
# Processing Record 40 of Set 9 | maniitsoq
# Processing Record 41 of Set 9 | zharkent
# Processing Record 42 of Set 9 | bafoulabe
# Processing Record 43 of Set 9 | bonthe
# Processing Record 44 of Set 9 | niquero
# Processing Record 45 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 46 of Set 9 | novobirilyussy
# Processing Record 47 of Set 9 | lima
# Processing Record 48 of Set 9 | lagoa
# Processing Record 49 of Set 9 | biak
# Processing Record 50 of Set 9 | raga
# Processing Record 1 of Set 10 | tamiahua
# Processing Record 2 of Set 10 | geresk
# City not found. Skipping...
# Processing Record 3 of Set 10 | atambua
# Processing Record 4 of Set 10 | pudozh
# Processing Record 5 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 6 of Set 10 | richards bay
# Processing Record 7 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 8 of Set 10 | pombia
# Processing Record 9 of Set 10 | paragominas
# Processing Record 10 of Set 10 | ajdabiya
# Processing Record 11 of Set 10 | namwala
# Processing Record 12 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 13 of Set 10 | chontalpa
# Processing Record 14 of Set 10 | riviere-au-renard
# Processing Record 15 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 16 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 10 | leningradskiy
# Processing Record 18 of Set 10 | gat
# Processing Record 19 of Set 10 | talaya
# Processing Record 20 of Set 10 | gomel
# Processing Record 21 of Set 10 | vestmanna
# Processing Record 22 of Set 10 | torbay
# Processing Record 23 of Set 10 | honningsvag
# Processing Record 24 of Set 10 | carikar
# City not found. Skipping...
# Processing Record 25 of Set 10 | ribeira do pombal
# Processing Record 26 of Set 10 | nome
# Processing Record 27 of Set 10 | saint-augustin
# Processing Record 28 of Set 10 | alofi
# Processing Record 29 of Set 10 | asfi
# Processing Record 30 of Set 10 | albion
# Processing Record 31 of Set 10 | tura
# Processing Record 32 of Set 10 | chivay
# Processing Record 33 of Set 10 | bengkulu
# Processing Record 34 of Set 10 | saint anthony
# Processing Record 35 of Set 10 | sarai
# Processing Record 36 of Set 10 | mukhen
# Processing Record 37 of Set 10 | rognac
# Processing Record 38 of Set 10 | vanavara
# Processing Record 39 of Set 10 | inongo
# Processing Record 40 of Set 10 | bathsheba
# Processing Record 41 of Set 10 | souillac
# Processing Record 42 of Set 10 | yarega
# Processing Record 43 of Set 10 | waseca
# Processing Record 44 of Set 10 | freetown
# Processing Record 45 of Set 10 | jasper
# Processing Record 46 of Set 10 | umm qays
# Processing Record 47 of Set 10 | plock
# Processing Record 48 of Set 10 | cacu
# Processing Record 49 of Set 10 | rawson
# Processing Record 50 of Set 10 | san quintin
# Processing Record 1 of Set 11 | sao gabriel da cachoeira
# Processing Record 2 of Set 11 | kajaani
# Processing Record 3 of Set 11 | kouango
# Processing Record 4 of Set 11 | suchedniow
# Processing Record 5 of Set 11 | khanpur
# Processing Record 6 of Set 11 | vanino
# Processing Record 7 of Set 11 | coahuayana
# Processing Record 8 of Set 11 | weihai
# Processing Record 9 of Set 11 | kem
# Processing Record 10 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 11 of Set 11 | nhulunbuy
# Processing Record 12 of Set 11 | burgos
# Processing Record 13 of Set 11 | nazira
# Processing Record 14 of Set 11 | ferrol
# Processing Record 15 of Set 11 | onega
# Processing Record 16 of Set 11 | tshikapa
# Processing Record 17 of Set 11 | kijang
# Processing Record 18 of Set 11 | akyab
# Processing Record 19 of Set 11 | sonari
# Processing Record 20 of Set 11 | tazovskiy
# Processing Record 21 of Set 11 | carutapera
# Processing Record 22 of Set 11 | awbari
# Processing Record 23 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 24 of Set 11 | san juan
# Processing Record 25 of Set 11 | orapa
# Processing Record 26 of Set 11 | ahipara
# Processing Record 27 of Set 11 | waimana
# Processing Record 28 of Set 11 | hohhot
# Processing Record 29 of Set 11 | akureyri
# Processing Record 30 of Set 11 | meulaboh
# Processing Record 31 of Set 11 | port blair
# Processing Record 32 of Set 11 | mogadishu
# Processing Record 33 of Set 11 | fallon
# Processing Record 34 of Set 11 | adrar
# Processing Record 35 of Set 11 | ilulissat
# Processing Record 36 of Set 11 | kumluca
# Processing Record 37 of Set 11 | bilibino
# Processing Record 38 of Set 11 | kenai
# Processing Record 39 of Set 11 | roselle
# Processing Record 40 of Set 11 | mareeba
# Processing Record 41 of Set 11 | venado
# Processing Record 42 of Set 11 | maxixe
# Processing Record 43 of Set 11 | gweta
# Processing Record 44 of Set 11 | chinsali
# Processing Record 45 of Set 11 | udachnyy
# Processing Record 46 of Set 11 | moerai
# Processing Record 47 of Set 11 | pandan niog
# Processing Record 48 of Set 11 | san-pedro
# Processing Record 49 of Set 11 | ust-kalmanka
# Processing Record 50 of Set 11 | mishelevka
# Processing Record 1 of Set 12 | borba
# Processing Record 2 of Set 12 | belyy yar
# Processing Record 3 of Set 12 | tulum
# Processing Record 4 of Set 12 | muzhi
# Processing Record 5 of Set 12 | perth
# Processing Record 6 of Set 12 | tucuma
# Processing Record 7 of Set 12 | kitaibaraki
# Processing Record 8 of Set 12 | edwardsville
# Processing Record 9 of Set 12 | kapoeta
# Processing Record 10 of Set 12 | sale
# Processing Record 11 of Set 12 | kondoa
# Processing Record 12 of Set 12 | shache
# Processing Record 13 of Set 12 | matara
# Processing Record 14 of Set 12 | oropesa
# Processing Record 15 of Set 12 | qarqin
# Processing Record 16 of Set 12 | lazaro cardenas
# Processing Record 17 of Set 12 | kamina
# Processing Record 18 of Set 12 | formosa
# Processing Record 19 of Set 12 | kushmurun
# Processing Record 20 of Set 12 | yar-sale
# Processing Record 21 of Set 12 | samarai
# Processing Record 22 of Set 12 | ternate
# Processing Record 23 of Set 12 | tocopilla
# Processing Record 24 of Set 12 | muli
# Processing Record 25 of Set 12 | umm kaddadah
# Processing Record 26 of Set 12 | umtata
# Processing Record 27 of Set 12 | kenora
# Processing Record 28 of Set 12 | kholm
# Processing Record 29 of Set 12 | celestun
# Processing Record 30 of Set 12 | avera
# Processing Record 31 of Set 12 | urambo
# Processing Record 32 of Set 12 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 33 of Set 12 | saint-georges
# Processing Record 34 of Set 12 | merzifon
# Processing Record 35 of Set 12 | sambhar
# Processing Record 36 of Set 12 | boguchany
# Processing Record 37 of Set 12 | christchurch
# Processing Record 38 of Set 12 | the valley
# Processing Record 39 of Set 12 | salisbury
# Processing Record 40 of Set 12 | la ronge
# Processing Record 41 of Set 12 | constitucion
# Processing Record 42 of Set 12 | qianan
# Processing Record 43 of Set 12 | jinchang
# Processing Record 44 of Set 12 | san jose
# Processing Record 45 of Set 12 | hovd
# Processing Record 46 of Set 12 | vangaindrano
# Processing Record 47 of Set 12 | sorland
# Processing Record 48 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 49 of Set 12 | charters towers
# Processing Record 50 of Set 12 | samana
# Processing Record 1 of Set 13 | katsuura
# Processing Record 2 of Set 13 | macau
# Processing Record 3 of Set 13 | bodden town
# Processing Record 4 of Set 13 | yuzhne
# Processing Record 5 of Set 13 | xadani
# City not found. Skipping...
# Processing Record 6 of Set 13 | point fortin
# Processing Record 7 of Set 13 | geraldton
# Processing Record 8 of Set 13 | tutoia
# Processing Record 9 of Set 13 | sao felix do xingu
# Processing Record 10 of Set 13 | ituiutaba
# Processing Record 11 of Set 13 | gander
# Processing Record 12 of Set 13 | timmins
# Processing Record 13 of Set 13 | wanning
# Processing Record 14 of Set 13 | marabba
# Processing Record 15 of Set 13 | rongcheng
# Processing Record 16 of Set 13 | vrangel
# Processing Record 17 of Set 13 | abhar
# Processing Record 18 of Set 13 | mitu
# Processing Record 19 of Set 13 | chara
# Processing Record 20 of Set 13 | matagami
# Processing Record 21 of Set 13 | faaa
# Processing Record 22 of Set 13 | tilichiki
# Processing Record 23 of Set 13 | haines junction
# Processing Record 24 of Set 13 | terre-de-bas
# Processing Record 25 of Set 13 | mahadday weyne
# City not found. Skipping...
# Processing Record 26 of Set 13 | arroyo
# Processing Record 27 of Set 13 | deshna
# City not found. Skipping...
# Processing Record 28 of Set 13 | port lincoln
# Processing Record 29 of Set 13 | sambava
# Processing Record 30 of Set 13 | zambezi
# Processing Record 31 of Set 13 | aykhal
# Processing Record 32 of Set 13 | coronado
# Processing Record 33 of Set 13 | northam
# Processing Record 34 of Set 13 | brae
# Processing Record 35 of Set 13 | sistranda
# Processing Record 36 of Set 13 | tabuk
# Processing Record 37 of Set 13 | papasquiaro
# City not found. Skipping...
# Processing Record 38 of Set 13 | aras
# Processing Record 39 of Set 13 | lauro muller
# Processing Record 40 of Set 13 | virginia beach
# Processing Record 41 of Set 13 | axim
# Processing Record 42 of Set 13 | grottammare
# Processing Record 43 of Set 13 | ascension
# Processing Record 44 of Set 13 | biharamulo
# Processing Record 45 of Set 13 | santa vitoria do palmar
# Processing Record 46 of Set 13 | luganville
# Processing Record 47 of Set 13 | valparaiso
# Processing Record 48 of Set 13 | surt
# Processing Record 49 of Set 13 | meadow lake
# Processing Record 50 of Set 13 | najran
# Processing Record 1 of Set 14 | osypenko
# Processing Record 2 of Set 14 | necochea
# Processing Record 3 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 4 of Set 14 | rio grande
# Processing Record 5 of Set 14 | kholodnyy
# Processing Record 6 of Set 14 | bardsir
# Processing Record 7 of Set 14 | bull savanna
# Processing Record 8 of Set 14 | guarapari
# Processing Record 9 of Set 14 | manzhouli
# Processing Record 10 of Set 14 | hofn
# Processing Record 11 of Set 14 | port hardy
# Processing Record 12 of Set 14 | dunedin
# Processing Record 13 of Set 14 | wuwei
# Processing Record 14 of Set 14 | kupang
# Processing Record 15 of Set 14 | mehran
# Processing Record 16 of Set 14 | karratha
# Processing Record 17 of Set 14 | bahia honda
# Processing Record 18 of Set 14 | fereydun kenar
# Processing Record 19 of Set 14 | alihe
# Processing Record 20 of Set 14 | porto novo
# Processing Record 21 of Set 14 | fillan
# Processing Record 22 of Set 14 | waitati
# Processing Record 23 of Set 14 | cahul
# Processing Record 24 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 25 of Set 14 | mersing
# Processing Record 26 of Set 14 | cubuk
# Processing Record 27 of Set 14 | saint-pierre
# Processing Record 28 of Set 14 | zinder
# Processing Record 29 of Set 14 | oktyabrskoye
# Processing Record 30 of Set 14 | bonfim
# Processing Record 31 of Set 14 | sharjah
# Processing Record 32 of Set 14 | bonavista
# Processing Record 33 of Set 14 | ucluelet
# Processing Record 34 of Set 14 | coquimbo
# Processing Record 35 of Set 14 | ust-tsilma
# Processing Record 36 of Set 14 | nova vicosa
# Processing Record 37 of Set 14 | ndioum
# Processing Record 38 of Set 14 | margate
# Processing Record 39 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 14 | chukhloma
# Processing Record 41 of Set 14 | vao
# Processing Record 42 of Set 14 | ingham
# Processing Record 43 of Set 14 | chicama
# Processing Record 44 of Set 14 | nueve de julio
# Processing Record 45 of Set 14 | katobu
# Processing Record 46 of Set 14 | sattenapalle
# Processing Record 47 of Set 14 | nouakchott
# Processing Record 48 of Set 14 | la libertad
# Processing Record 49 of Set 14 | zaysan
# Processing Record 50 of Set 14 | mpongwe
# Processing Record 1 of Set 15 | skibbereen
# Processing Record 2 of Set 15 | muros
# Processing Record 3 of Set 15 | makaha
# Processing Record 4 of Set 15 | severo-yeniseyskiy
# Processing Record 5 of Set 15 | marystown
# Processing Record 6 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 7 of Set 15 | arica
# Processing Record 8 of Set 15 | imphal
# Processing Record 9 of Set 15 | sundargarh
# Processing Record 10 of Set 15 | broome
# Processing Record 11 of Set 15 | pacifica
# Processing Record 12 of Set 15 | ninh binh
# Processing Record 13 of Set 15 | nantucket
# Processing Record 14 of Set 15 | havre-saint-pierre
# Processing Record 15 of Set 15 | yilan
# Processing Record 16 of Set 15 | heihe
# Processing Record 17 of Set 15 | gorontalo
# Processing Record 18 of Set 15 | kota kinabalu
# Processing Record 19 of Set 15 | lincoln
# Processing Record 20 of Set 15 | mandera
# Processing Record 21 of Set 15 | palu
# Processing Record 22 of Set 15 | linxia
# Processing Record 23 of Set 15 | rimavska sobota
# Processing Record 24 of Set 15 | evansville
# Processing Record 25 of Set 15 | harper
# Processing Record 26 of Set 15 | ormara
# Processing Record 27 of Set 15 | dumbraveni
# Processing Record 28 of Set 15 | joshimath
# Processing Record 29 of Set 15 | santa catarina de tepehuanes
# Processing Record 30 of Set 15 | orlik
# Processing Record 31 of Set 15 | espanola
# Processing Record 32 of Set 15 | talcahuano
# Processing Record 33 of Set 15 | udarnyy
# Processing Record 34 of Set 15 | karasjok
# Processing Record 35 of Set 15 | niquelandia
# Processing Record 36 of Set 15 | krasnaya gorka
# Processing Record 37 of Set 15 | beyneu
# Processing Record 38 of Set 15 | lalibela
# Processing Record 39 of Set 15 | ojinaga
# Processing Record 40 of Set 15 | sept-iles
# Processing Record 41 of Set 15 | port-cartier
# Processing Record 42 of Set 15 | imatra
# Processing Record 43 of Set 15 | acari
# Processing Record 44 of Set 15 | acarau
# Processing Record 45 of Set 15 | blind river
# Processing Record 46 of Set 15 | nizwa
# Processing Record 47 of Set 15 | zhitikara
# City not found. Skipping...
# Processing Record 48 of Set 15 | saint-joseph
# Processing Record 49 of Set 15 | tianpeng
# Processing Record 50 of Set 15 | katherine
# Processing Record 1 of Set 16 | shurugwi
# Processing Record 2 of Set 16 | labuan
# Processing Record 3 of Set 16 | doka
# Processing Record 4 of Set 16 | lasa
# Processing Record 5 of Set 16 | rouvroy
# Processing Record 6 of Set 16 | progreso
# Processing Record 7 of Set 16 | alice springs
# Processing Record 8 of Set 16 | saint-jean-de-maurienne
# Processing Record 9 of Set 16 | davenda
# Processing Record 10 of Set 16 | yulara
# Processing Record 11 of Set 16 | maraa
# Processing Record 12 of Set 16 | issia
# Processing Record 13 of Set 16 | barinas
# Processing Record 14 of Set 16 | ambon
# Processing Record 15 of Set 16 | yelizovo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 703

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Jamestown  42.0970  -79.2353     49.59        63          20
# 1        Xilitla  21.3333  -98.9667     74.71        82          49
# 2         Atuona  -9.8000 -139.0333     79.07        78          21
# 3  Mar Del Plata -38.0023  -57.5575     57.09        87           0
# 4   Punta Arenas -53.1500  -70.9167     46.51        87           0
# 5      Kalianget  -7.0500  113.9333     85.62        69          91
# 6       Cidreira -30.1811  -50.2056     64.20        69          90
# 7     Bredasdorp -34.5322   20.0403     58.30        60          99
# 8      Thinadhoo   0.5333   72.9333     82.65        72          31
# 9        Bignona  12.8103  -16.2264     69.84        63          63
#
#    Wind Speed Country Weather Description
# 0        8.05      US          few clouds
# 1        2.80      MX    scattered clouds
# 2       16.08      PF          light rain
# 3        8.01      AR           clear sky
# 4       11.50      CL           clear sky
# 5        3.49      ID     overcast clouds
# 6        7.43      BR     overcast clouds
# 7       11.52      ZA     overcast clouds
# 8        3.40      MV    scattered clouds
# 9        9.86      SN       broken clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Jamestown      US  42.0970  -79.2353     49.59        63          20
# 1        Xilitla      MX  21.3333  -98.9667     74.71        82          49
# 2         Atuona      PF  -9.8000 -139.0333     79.07        78          21
# 3  Mar Del Plata      AR -38.0023  -57.5575     57.09        87           0
# 4   Punta Arenas      CL -53.1500  -70.9167     46.51        87           0
# 5      Kalianget      ID  -7.0500  113.9333     85.62        69          91
# 6       Cidreira      BR -30.1811  -50.2056     64.20        69          90
# 7     Bredasdorp      ZA -34.5322   20.0403     58.30        60          99
# 8      Thinadhoo      MV   0.5333   72.9333     82.65        72          31
# 9        Bignona      SN  12.8103  -16.2264     69.84        63          63
#
#    Wind Speed Weather Description
# 0        8.05          few clouds
# 1        2.80    scattered clouds
# 2       16.08          light rain
# 3        8.01           clear sky
# 4       11.50           clear sky
# 5        3.49     overcast clouds
# 6        7.43     overcast clouds
# 7       11.52     overcast clouds
# 8        3.40    scattered clouds
# 9        9.86       broken clouds

# %%
city_data_df = city_data_df.rename(columns = {'Weather Description':'Current Description'})
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Jamestown      US  42.0970  -79.2353     49.59        63          20
# 1        Xilitla      MX  21.3333  -98.9667     74.71        82          49
# 2         Atuona      PF  -9.8000 -139.0333     79.07        78          21
# 3  Mar Del Plata      AR -38.0023  -57.5575     57.09        87           0
# 4   Punta Arenas      CL -53.1500  -70.9167     46.51        87           0
# 5      Kalianget      ID  -7.0500  113.9333     85.62        69          91
# 6       Cidreira      BR -30.1811  -50.2056     64.20        69          90
# 7     Bredasdorp      ZA -34.5322   20.0403     58.30        60          99
# 8      Thinadhoo      MV   0.5333   72.9333     82.65        72          31
# 9        Bignona      SN  12.8103  -16.2264     69.84        63          63
#
#    Wind Speed Current Description
# 0        8.05          few clouds
# 1        2.80    scattered clouds
# 2       16.08          light rain
# 3        8.01           clear sky
# 4       11.50           clear sky
# 5        3.49     overcast clouds
# 6        7.43     overcast clouds
# 7       11.52     overcast clouds
# 8        3.40    scattered clouds
# 9        9.86       broken clouds

# %%
# Export to cvs file
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
city_data_df.isnull().sum()
# Out:
# City                   0
# Country                0
# Lat                    0
# Lng                    0
# Max Temp               0
# Humidity               0
# Cloudiness             0
# Wind Speed             0
# Current Description    0
# dtype: int64
